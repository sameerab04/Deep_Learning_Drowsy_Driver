# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import cv2 as cv
import matplotlib.pyplot as plt
import os
import shutil
from sklearn.model_selection import train_test_split
import keras_tuner as kt

CLASSES = 2
BATCH_SIZE = 16
input_size = 244

# %%
tf.random.set_seed(123)
np.random.seed(123)

# %%
import os
import pandas as pd

def create_dataframe(data_folders, split_folders):
    dfs = []

    for data_folder in data_folders:
        for split_folder in split_folders:
            path_folder = os.path.join(data_folder, split_folder)
            image_folder = os.path.join(path_folder, 'images')
            label_folder = os.path.join(path_folder, 'labels')

            # List the files in both directories
            images = sorted(os.listdir(image_folder))
            labels = sorted(os.listdir(label_folder))

            # Create full paths for images and labels
            image_paths = [os.path.join(image_folder, img) for img in images]
            label_paths = [os.path.join(label_folder, lbl) for lbl in labels]

            x = []
            y = []
            w = []
            h = []

            # read the four indices for bounding boxes
            for label_path in label_paths:
                with open(label_path, 'r') as file:
                    # Read each line in the file one by one
                    for line in file:
                        bounding_idx = line.split(" ")

                x.append(bounding_idx[1])
                y.append(bounding_idx[2])
                w.append(bounding_idx[3])
                h.append(bounding_idx[4])

            # Create a DataFrame
            df = pd.DataFrame({
                'image_path': image_paths,
                'label_x': x,
                'label_y': y,
                'label_w': w,
                'label_h': h
            })

            dfs.append(df)

    return dfs

# Usage
data_folders = ["../../Drowsey_Driver_DL_Data/data_objectdetection/1/dl_project.v1i.yolov8", 
                "../../Drowsey_Driver_DL_Data/data_objectdetection/2/DrowsyDriverDetection.v1i.yolov8",
                "../../Drowsey_Driver_DL_Data/data_objectdetection/3/dl_images.v1i.yolov8", 
                "../../Drowsey_Driver_DL_Data/data_objectdetection/4/Drowsy Driver.v1i.yolov8"]
split_folders = ["train", "test"]

dfs = create_dataframe(data_folders, split_folders)

# Separate DataFrames for each split folder

train_dfs = dfs[:len(data_folders)]
test_dfs = dfs[len(data_folders):]

# Concatenate the DataFrames
train_df = pd.concat(train_dfs, ignore_index=True)
test_df = pd.concat(test_dfs, ignore_index=True)

# Convert columns to float
train_df[['label_x', 'label_y', 'label_w', 'label_h']] = train_df[['label_x', 'label_y', 'label_w', 'label_h']].astype(float)
test_df[['label_x', 'label_y', 'label_w', 'label_h']] = test_df[['label_x', 'label_y', 'label_w', 'label_h']].astype(float)

# Split the combined train dataframe into train and validation sets
train_df, val_df = train_test_split(train_df, test_size=0.1, random_state=42)

# Print the shapes of train and validation sets
print("Train data shape:", train_df.shape)
print("Validation data shape:", val_df.shape)
train_df.head(5)
# Out:
# Train data shape: (531, 5)
# Validation data shape: (59, 5)
#                                             image_path   label_x   label_y  \
# 316  ../../Drowsey_Driver_DL_Data/data_objectdetect...  0.464844  0.256250
# 76   ../../Drowsey_Driver_DL_Data/data_objectdetect...  0.378125  0.372656
# 529  ../../Drowsey_Driver_DL_Data/data_objectdetect...  0.575781  0.282813
# 446  ../../Drowsey_Driver_DL_Data/data_objectdetect...  0.532031  0.336719
# 30   ../../Drowsey_Driver_DL_Data/data_objectdetect...  0.414844  0.339844
#
#       label_w   label_h
# 316  0.131250  0.135937
# 76   0.375000  0.203125
# 529  0.156250  0.182812
# 446  0.148438  0.184375
# 30   0.467969  0.093750

# %%
def format_image(img, box):
    height, width = img.shape
    max_size = max(height, width)
    r = max_size / input_size
    new_width = int(width / r)
    new_height = int(height / r)
    new_size = (new_width, new_height)
    resized = cv.resize(img, new_size, interpolation= cv.INTER_LINEAR)
    new_image = np.zeros((input_size, input_size), dtype=np.uint8)
    new_image[0:new_height, 0:new_width] = resized

    x, y, w, h = box[0], box[1], box[2], box[3]
    new_box = [int((x - 0.5*w)* width / r), int((y - 0.5*h) * height / r), int(w*width / r), int(h*height / r)]

    return new_image, new_box

# %%
import cv2 as cv
import numpy as np
import tensorflow as tf

def data_load(df):
    X = []
    Y = []

    # Iterate through each row in the DataFrame
    for idx, row in df.iterrows():
        # Load the image from the full path specified in the 'image_path' column
        img = cv.imread(row['image_path'], cv.IMREAD_GRAYSCALE)
        if img is None:
            continue

        # Extract bounding box coordinates from the DataFrame
        box = np.array([row['label_x'], row['label_y'], row['label_w'], row['label_h']], dtype=float)

        # Normalize the image and adjust the bounding box
        img, box = format_image(img, box)
        img = img.astype(float) / 255.0

        # convert the bounding box indices back to (0,1) scale
        box = np.asarray(box, dtype=float) / input_size

        # Append the processed image and box to the lists
        X.append(img)
        Y.append(box)

    # Convert lists to numpy arrays
    X = np.array(X)
    X = np.expand_dims(X, axis=-1)  # Add a new axis to match the expected input shape of the model
    X = tf.convert_to_tensor(X, dtype=tf.float32)

    Y = np.array(Y)
    Y = tf.convert_to_tensor(Y, dtype=tf.float32)

    # Create a TensorFlow Dataset from the tensor slices
    result = tf.data.Dataset.from_tensor_slices((X, Y))

    return result

# %%
train_df = data_load(train_df)
val_df = data_load(val_df)
test_df = data_load(test_df)
# Out:
# 2024-05-30 15:32:16.797746: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M3 Pro
# 2024-05-30 15:32:16.797802: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 18.00 GB
# 2024-05-30 15:32:16.797805: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 6.00 GB
# 2024-05-30 15:32:16.799031: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-05-30 15:32:16.799065: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
train_df
# Out:
# <_TensorSliceDataset element_spec=(TensorSpec(shape=(244, 244, 1), dtype=tf.float32, name=None), TensorSpec(shape=(4,), dtype=tf.float32, name=None))>

# %%
def format_instance(image, label):
    # Assuming some preprocessing needed:
    # image = preprocess_image(image)  # Adjust preprocessing as necessary
    return image, [label[0], label[1], label[2], label[3]]

def tune_dataset(dataset, is_train=True):
    dataset = dataset.map(format_instance, num_parallel_calls=tf.data.AUTOTUNE)
    if is_train:
        dataset = dataset.shuffle(1024, reshuffle_each_iteration=True)
    dataset = dataset.batch(BATCH_SIZE)
    dataset = dataset.prefetch(tf.data.AUTOTUNE)
    return dataset

# Use generalized function for all datasets
train_ds = tune_dataset(train_df, is_train=True)
val_ds = tune_dataset(val_df, is_train=False)
test_ds = tune_dataset(test_df, is_train=False)

# %%
val_ds
# Out:
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 244, 244, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None, 4), dtype=tf.float32, name=None))>

# %%
plt.figure(figsize=(20, 10))
for images, boxes in val_ds.take(1):
    for i in range(BATCH_SIZE):
        ax = plt.subplot(4, BATCH_SIZE // 4, i + 1)

        # Retrieve the bounding box
        box = boxes[i].numpy() * input_size  # Scale the bounding box back to the original image size
        box = box.astype(int)  # Convert to integer for pixel coordinates

        # Calculate top-left and bottom-right coordinates
        x, y, w, h = box
        top_left = (x, y)
        bottom_right = (x + w, y + h)

        # Convert grayscale to RGB for visualization
        image = images[i].numpy() * 255.0  # Rescale the image
        image = image.astype(np.uint8)  # Convert to uint8 type
        image_color = cv.cvtColor(image, cv.COLOR_GRAY2RGB)

        # Draw the rectangle on the image
        cv.rectangle(image_color, top_left, bottom_right, (0, 255, 0), 2)

        # Display the image
        plt.imshow(image_color)
        plt.axis("off")

plt.show()
# Out:
# 2024-05-30 15:32:19.724233: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %%
import tensorflow as tf
from tensorflow.keras import layers, regularizers
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau

# Define a more complex CNN model with added regularization and dropout
model = tf.keras.models.Sequential([
    layers.Conv2D(64, (3, 3), activation='relu', input_shape=(input_size, input_size, 1)),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(128, (3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(256, (3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(512, (3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Flatten(),
    layers.Dense(256, activation='relu', kernel_regularizer=regularizers.l2(0.01)),
    layers.Dropout(0.5),
    layers.Dense(4, activation='sigmoid')
])

# Define IoU loss function
def iou_loss(y_true, y_pred):
    true_x, true_y, true_w, true_h = tf.split(y_true, 4, axis=-1)
    pred_x, pred_y, pred_w, pred_h = tf.split(y_pred, 4, axis=-1)

    intersect_x1 = tf.maximum(true_x - true_w / 2.0, pred_x - pred_w / 2.0)
    intersect_y1 = tf.maximum(true_y - true_h / 2.0, pred_y - pred_h / 2.0)
    intersect_x2 = tf.minimum(true_x + true_w / 2.0, pred_x + pred_w / 2.0)
    intersect_y2 = tf.minimum(true_y + true_h / 2.0, pred_y + pred_h / 2.0)

    intersect_area = tf.maximum(0.0, intersect_x2 - intersect_x1) * tf.maximum(0.0, intersect_y2 - intersect_y1)
    true_area = true_w * true_h
    pred_area = pred_w * pred_h
    union_area = true_area + pred_area - intersect_area
    iou = intersect_area / union_area

    return 1.0 - iou

def iou_metric(y_true, y_pred):
    true_x, true_y, true_w, true_h = tf.split(y_true, 4, axis=-1)
    pred_x, pred_y, pred_w, pred_h = tf.split(y_pred, 4, axis=-1)

    intersect_x1 = tf.maximum(true_x - true_w / 2.0, pred_x - pred_w / 2.0)
    intersect_y1 = tf.maximum(true_y - true_h / 2.0, pred_y - pred_h / 2.0)
    intersect_x2 = tf.minimum(true_x + true_w / 2.0, pred_x + pred_w / 2.0)
    intersect_y2 = tf.minimum(true_y + true_h / 2.0, pred_y + pred_h / 2.0)

    intersect_area = tf.maximum(0.0, intersect_x2 - intersect_x1) * tf.maximum(0.0, intersect_y2 - intersect_y1)
    true_area = true_w * true_h
    pred_area = pred_w * pred_h
    union_area = true_area + pred_area - intersect_area
    iou = intersect_area / union_area

    return iou

# Compile the model with IoU loss
model.compile(optimizer=Adam(learning_rate=0.001), loss=iou_loss, metrics=[iou_metric])


# Implement learning rate scheduling
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=3, min_lr=1e-6)

# Train the model with hyperparameter tuning and learning rate scheduling
history = model.fit(train_ds, validation_data=val_ds, epochs=50, callbacks=[reduce_lr])

# Evaluate the model
loss, iou = model.evaluate(val_ds)
print("Validation IoU:", iou)
# Out:
# Epoch 1/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 8s 187ms/step - iou_metric: 0.0817 - loss: 2.4702 - val_iou_metric: 0.1815 - val_loss: 0.9553 - learning_rate: 0.0010
# Epoch 2/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 6s 174ms/step - iou_metric: 0.2137 - loss: 0.8943 - val_iou_metric: 0.3090 - val_loss: 0.8053 - learning_rate: 0.0010
# Epoch 3/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 6s 162ms/step - iou_metric: 0.2825 - loss: 0.8249 - val_iou_metric: 0.3022 - val_loss: 0.7964 - learning_rate: 0.0010
# Epoch 4/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 5s 161ms/step - iou_metric: 0.2980 - loss: 0.7980 - val_iou_metric: 0.4159 - val_loss: 0.6722 - learning_rate: 0.0010
# Epoch 5/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 5s 157ms/step - iou_metric: 0.3741 - loss: 0.7110 - val_iou_metric: 0.3835 - val_loss: 0.6870 - learning_rate: 0.0010
# Epoch 6/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 5s 160ms/step - iou_metric: 0.3572 - loss: 0.7171 - val_iou_metric: 0.4236 - val_loss: 0.6531 - learning_rate: 0.0010
# Epoch 7/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 5s 159ms/step - iou_metric: 0.3994 - loss: 0.6813 - val_iou_metric: 0.5357 - val_loss: 0.5416 - learning_rate: 0.0010
# Epoch 8/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 5s 156ms/step - iou_metric: 0.4047 - loss: 0.6713 - val_iou_metric: 0.5567 - val_loss: 0.5128 - learning_rate: 0.0010
# Epoch 9/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 5s 160ms/step - iou_metric: 0.4313 - loss: 0.6419 - val_iou_metric: 0.4427 - val_loss: 0.6383 - learning_rate: 0.0010
# Epoch 10/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 5s 160ms/step - iou_metric: 0.4168 - loss: 0.6639 - val_iou_metric: 0.5105 - val_loss: 0.5585 - learning_rate: 0.0010
# Epoch 11/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 5s 155ms/step - iou_metric: 0.4581 - loss: 0.6113 - val_iou_metric: 0.6127 - val_loss: 0.4497 - learning_rate: 0.0010
# Epoch 12/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 5s 162ms/step - iou_metric: 0.4595 - loss: 0.6106 - val_iou_metric: 0.5188 - val_loss: 0.5523 - learning_rate: 0.0010
# Epoch 13/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 6s 176ms/step - iou_metric: 0.4363 - loss: 0.6322 - val_iou_metric: 0.5772 - val_loss: 0.4913 - learning_rate: 0.0010
# Epoch 14/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 6s 168ms/step - iou_metric: 0.4833 - loss: 0.5809 - val_iou_metric: 0.6485 - val_loss: 0.4149 - learning_rate: 0.0010
# Epoch 15/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 5s 160ms/step - iou_metric: 0.4829 - loss: 0.5874 - val_iou_metric: 0.6355 - val_loss: 0.4368 - learning_rate: 0.0010
# Epoch 16/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 5s 157ms/step - iou_metric: 0.5085 - loss: 0.5666 - val_iou_metric: 0.6329 - val_loss: 0.4281 - learning_rate: 0.0010
# Epoch 17/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 5s 158ms/step - iou_metric: 0.5166 - loss: 0.5462 - val_iou_metric: 0.6674 - val_loss: 0.4014 - learning_rate: 0.0010
# Epoch 18/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 5s 157ms/step - iou_metric: 0.5306 - loss: 0.5354 - val_iou_metric: 0.6255 - val_loss: 0.4453 - learning_rate: 0.0010
# Epoch 19/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 5s 156ms/step - iou_metric: 0.5038 - loss: 0.5647 - val_iou_metric: 0.6392 - val_loss: 0.4191 - learning_rate: 0.0010
# Epoch 20/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 5s 155ms/step - iou_metric: 0.5258 - loss: 0.5303 - val_iou_metric: 0.4946 - val_loss: 0.5619 - learning_rate: 0.0010
# Epoch 21/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 5s 156ms/step - iou_metric: 0.4876 - loss: 0.5669 - val_iou_metric: 0.7050 - val_loss: 0.3457 - learning_rate: 2.0000e-04
# Epoch 22/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 5s 156ms/step - iou_metric: 0.5516 - loss: 0.4983 - val_iou_metric: 0.5892 - val_loss: 0.4553 - learning_rate: 2.0000e-04
# Epoch 23/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 6s 169ms/step - iou_metric: 0.5138 - loss: 0.5304 - val_iou_metric: 0.6850 - val_loss: 0.3579 - learning_rate: 2.0000e-04
# Epoch 24/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 6s 162ms/step - iou_metric: 0.5620 - loss: 0.4806 - val_iou_metric: 0.7255 - val_loss: 0.3156 - learning_rate: 2.0000e-04
# Epoch 25/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 5s 158ms/step - iou_metric: 0.5667 - loss: 0.4739 - val_iou_metric: 0.7109 - val_loss: 0.3280 - learning_rate: 2.0000e-04
# Epoch 26/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 5s 157ms/step - iou_metric: 0.5699 - loss: 0.4688 - val_iou_metric: 0.7224 - val_loss: 0.3153 - learning_rate: 2.0000e-04
# Epoch 27/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 5s 155ms/step - iou_metric: 0.5796 - loss: 0.4578 - val_iou_metric: 0.7206 - val_loss: 0.3156 - learning_rate: 2.0000e-04
# Epoch 28/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 5s 155ms/step - iou_metric: 0.5624 - loss: 0.4734 - val_iou_metric: 0.7309 - val_loss: 0.3042 - learning_rate: 2.0000e-04
# Epoch 29/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 5s 156ms/step - iou_metric: 0.5756 - loss: 0.4592 - val_iou_metric: 0.7218 - val_loss: 0.3121 - learning_rate: 2.0000e-04
# Epoch 30/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 5s 156ms/step - iou_metric: 0.5883 - loss: 0.4455 - val_iou_metric: 0.7191 - val_loss: 0.3140 - learning_rate: 2.0000e-04
# Epoch 31/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 5s 156ms/step - iou_metric: 0.5795 - loss: 0.4534 - val_iou_metric: 0.7191 - val_loss: 0.3132 - learning_rate: 2.0000e-04
# Epoch 32/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 5s 156ms/step - iou_metric: 0.5867 - loss: 0.4456 - val_iou_metric: 0.7410 - val_loss: 0.2911 - learning_rate: 4.0000e-05
# Epoch 33/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 5s 155ms/step - iou_metric: 0.5840 - loss: 0.4481 - val_iou_metric: 0.7451 - val_loss: 0.2866 - learning_rate: 4.0000e-05
# Epoch 34/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 5s 154ms/step - iou_metric: 0.5997 - loss: 0.4319 - val_iou_metric: 0.7439 - val_loss: 0.2872 - learning_rate: 4.0000e-05
# Epoch 35/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 5s 154ms/step - iou_metric: 0.5995 - loss: 0.4314 - val_iou_metric: 0.7366 - val_loss: 0.2940 - learning_rate: 4.0000e-05
# Epoch 36/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 5s 156ms/step - iou_metric: 0.5798 - loss: 0.4508 - val_iou_metric: 0.7458 - val_loss: 0.2846 - learning_rate: 4.0000e-05
# Epoch 37/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 6s 163ms/step - iou_metric: 0.5929 - loss: 0.4375 - val_iou_metric: 0.7422 - val_loss: 0.2880 - learning_rate: 4.0000e-05
# Epoch 38/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 5s 156ms/step - iou_metric: 0.6043 - loss: 0.4258 - val_iou_metric: 0.7454 - val_loss: 0.2843 - learning_rate: 4.0000e-05
# Epoch 39/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 5s 156ms/step - iou_metric: 0.5915 - loss: 0.4380 - val_iou_metric: 0.7360 - val_loss: 0.2933 - learning_rate: 4.0000e-05
# Epoch 40/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 5s 161ms/step - iou_metric: 0.5890 - loss: 0.4402 - val_iou_metric: 0.7573 - val_loss: 0.2720 - learning_rate: 4.0000e-05
# Epoch 41/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 5s 156ms/step - iou_metric: 0.5766 - loss: 0.4527 - val_iou_metric: 0.7272 - val_loss: 0.3015 - learning_rate: 4.0000e-05
# Epoch 42/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 5s 156ms/step - iou_metric: 0.5913 - loss: 0.4375 - val_iou_metric: 0.7455 - val_loss: 0.2830 - learning_rate: 4.0000e-05
# Epoch 43/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 5s 154ms/step - iou_metric: 0.5971 - loss: 0.4315 - val_iou_metric: 0.7552 - val_loss: 0.2732 - learning_rate: 4.0000e-05
# Epoch 44/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 5s 154ms/step - iou_metric: 0.5949 - loss: 0.4335 - val_iou_metric: 0.7446 - val_loss: 0.2836 - learning_rate: 8.0000e-06
# Epoch 45/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 5s 154ms/step - iou_metric: 0.5997 - loss: 0.4285 - val_iou_metric: 0.7523 - val_loss: 0.2759 - learning_rate: 8.0000e-06
# Epoch 46/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 5s 162ms/step - iou_metric: 0.6009 - loss: 0.4273 - val_iou_metric: 0.7496 - val_loss: 0.2786 - learning_rate: 8.0000e-06
# Epoch 47/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 5s 160ms/step - iou_metric: 0.5910 - loss: 0.4371 - val_iou_metric: 0.7500 - val_loss: 0.2781 - learning_rate: 1.6000e-06
# Epoch 48/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 5s 157ms/step - iou_metric: 0.6012 - loss: 0.4269 - val_iou_metric: 0.7482 - val_loss: 0.2799 - learning_rate: 1.6000e-06
# Epoch 49/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 5s 156ms/step - iou_metric: 0.6028 - loss: 0.4252 - val_iou_metric: 0.7471 - val_loss: 0.2810 - learning_rate: 1.6000e-06
# Epoch 50/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 6s 167ms/step - iou_metric: 0.5728 - loss: 0.4553 - val_iou_metric: 0.7475 - val_loss: 0.2806 - learning_rate: 1.0000e-06
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - iou_metric: 0.7493 - loss: 0.2787
# Validation IoU: 0.7474900484085083

# %%
# Evaluate the model on the test dataset
test_loss, test_iou = model.evaluate(test_ds)
print("Test IoU:", test_iou)
# Out:
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - iou_metric: 0.0236 - loss: 1.0114
# Test IoU: 0.09928718954324722

# %%
# Use the trained model to predict bounding box coordinates for the dataset
test_predictions = model.predict(test_ds)
test_predictions
# Out:
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step
# array([[0.38733232, 0.02674115, 0.13753527, 0.08520284],
#        [0.4212409 , 0.02742201, 0.13768008, 0.08761944],
#        [0.40181854, 0.02906839, 0.15902132, 0.09299681],
#        ...,
#        [0.35759354, 0.26500636, 0.2864673 , 0.2015919 ],
#        [0.35676536, 0.26545745, 0.28878793, 0.20207761],
#        [0.33224994, 0.32277837, 0.3890538 , 0.24980631]], dtype=float32)

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import numpy as np
import tensorflow as tf

def visualize_predictions(images, predictions, num_images=5):
    fig, axs = plt.subplots(1, num_images, figsize=(15, 5))
    for i in range(num_images):
        img = images[i].numpy() if isinstance(images[i], tf.Tensor) else images[i]
        img = np.squeeze(img)
        # Assuming images are in grayscale and have been normalized
        axs[i].imshow(img, cmap='gray')
        axs[i].axis('off')

        # Normalize coordinates and dimensions
        x1, y1, w, h = predictions[i]
        # Adjust for image dimensions
        x1 *= img.shape[1]
        w *= img.shape[1]
        y1 *= img.shape[0]
        h *= img.shape[0]

        # Create a rectangle patch
        rect = patches.Rectangle((x1, y1), w, h, linewidth=2, edgecolor='r', facecolor='none')
        axs[i].add_patch(rect)

    plt.show()

# Assuming 'test_ds' is your validation dataset and 'model' is your trained model
for batch_number, (images, _) in enumerate(test_ds.take(1), 1):  # Take one batch
    print(f"Visualizing batch {batch_number}")
    preds = model.predict(images)  # Predict the bounding boxes
    visualize_predictions(images, preds)  # Visualize the predictions
# Out:
# Visualizing batch 1
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 2024-05-30 15:50:16.963792: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
